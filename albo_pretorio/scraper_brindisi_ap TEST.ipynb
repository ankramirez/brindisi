# %%
from datetime import datetime,date
from functools import wraps
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException, NoSuchWindowException, ElementNotInteractableException, StaleElementReferenceException
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from urllib.parse import urlparse, unquote

import csv
import hashlib
import logging
import os
import requests
import re
import time

from pathlib import Path
from typing import Tuple

# %%
logging.basicConfig()
logging.getLogger().setLevel(logging.INFO)

# %%
comune = 'brindisi'
download_path = './ap'
url_comune = 'https://servizi.comune.brindisi.it/openweb/albo/albo_pretorio.php'

# %%
def retry(max_attempts=3, delay=10, exceptions=(Exception,)):
    def decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            attempts = 0
            while attempts < max_attempts:
                try:
                    return func(*args, **kwargs)
                except exceptions as e:
                    attempts += 1
                    logging.info(f"Attempt {attempts} failed:", e)
                    time.sleep(delay)
            raise RuntimeError(f"Function {func.__name__} failed after {max_attempts} attempts")
        return wrapper
    return decorator

# %% [markdown]
# # Driver manager

# %%
class WebDriverManager:
    def __init__(self, DIR_DOWNLOAD):
        self.driver = None

    def start_driver(self, url):
        if not self.driver or (self.is_driver_open() == False):
            opts = Options()
            # start driver
            s = Service(r".\chromedriver.exe")
            prefs = {"download.default_directory": f'{download_path}',
                    "directory_upgrade": True,
                    "profile.default_content_settings.popups": 0}
            opts.add_experimental_option("prefs", prefs)
            self.driver = Chrome(service=s, options=opts)

            # opts = Options()
            # service = Service()

            # prefs = {"download.default_directory": f'{download_path}',
            #         "directory_upgrade": True,
            #         "profile.default_content_settings.popups": 0,
            #         "plugins.always_open_pdf_externally": True  # It will not show PDF directly in chrome
            #         }

            # opts.add_experimental_option('prefs', prefs)
            # opts.add_argument('--no-sandbox')
            # opts.add_argument('--headless')
            # opts.add_argument('--disable-gpu')
            # opts.add_argument('--disable-dev-shm-usage')

            # self.driver = Chrome(service=service,
            #                 options=opts)

            self.driver.get(url)
            # self.check_cookies()
            time.sleep(10) # Waiting for main page to load
        return self.driver  # Return the driver instance
        
    # No cookies button (?)
    # def check_cookies(self):
    #     try: 
    #         time.sleep(2)
    #         cookie_button = self.driver.find_element(By.CLASS_NAME, "btn.btn-primary.mr-2")

    #         cookie_button.click()
    #     except NoSuchElementException:
    #         logging.info(f'Cookies button was not found')
    #         pass
    #     except ElementNotInteractableException:
    #         pass

    def is_driver_open(self):
        if self.driver:
            try:
                # Access a property or method of the driver
                self.driver.current_url
                return True
            except NoSuchWindowException:
                return False
            except Exception as e:
                logging.info(f'Driver seems to be closed: {e}')
                return False
        return False
    
    def get_driver(self, link):
        if not self.is_driver_open():
            logging.warning(f'Driver is not responding, reopening')
            self.driver = self.start_driver(link)
        # else: 
        #     self.driver.get(link)
            # self.check_cookies()

        return self.driver

    def close_driver(self):
        if self.driver:
            self.driver.quit()
            self.driver = None

# %%
driver_manager = WebDriverManager(download_path)

# %%
driver = driver_manager.get_driver(url_comune)
# Out:
# WARNING:root:Driver is not responding, reopening

# %% [markdown]
# # Loop through all pages of a section

# %%
body_e = driver.find_element(By.ID, 'tabella_albo')

rows_e = body_e.find_elements(By.CLASS_NAME, 'paginated_element')

# %% [markdown]
# ## Processing dates

# %%
for r_e in rows_e:
    # Find the div containing 'Data affissione:'
    data_affissione_div = r_e.find_element(By.XPATH, ".//div[label/text()='Data affissione:']")
    # data_affissione_text = data_affissione_div.text.split("Data affissione:")[1].strip()

    # Find the div containing 'Fine Pubblicazione:'
    fine_pubblicazione_div = r_e.find_element(By.XPATH, ".//div[label/text()='Fine Pubblicazione:']")
    # fine_pubblicazione_text = fine_pubblicazione_div.text.split("Fine Pubblicazione:")[1].strip()

    print(data_affissione_div.text, fine_pubblicazione_div.text)
# Out:
# 06/06/2024 14/06/2024
# 06/06/2024 21/06/2024
# 06/06/2024 21/06/2024
# 06/06/2024 21/06/2024
# 06/06/2024 21/06/2024
# 06/06/2024 21/06/2024
# 06/06/2024 06/07/2024
# 05/06/2024 06/06/2024
# 05/06/2024 06/06/2024
# 05/06/2024 06/06/2024
# 05/06/2024 06/06/2024
# 05/06/2024 06/06/2024
# 05/06/2024 06/06/2024
# 05/06/2024 06/06/2024
# 05/06/2024 06/06/2024

# %%
# while True:
#     try:
#         # Waiting for the tabella element
#         body_e = WebDriverWait(driver, 10).until(
#             EC.presence_of_element_located((By.ID, 'tabella_albo'))
#         )

#         # Getting each row, one for each atto
#         rows_e = body_e.find_elements(By.CLASS_NAME, 'paginated_element')

#         # Process rows
#         if rows_e:
#             for r_e in rows_e:
#                 try:
#                     progressivo = r_e.find_element(By.TAG_NAME, 'div').text
#                     print(progressivo)
#                 except StaleElementReferenceException:
#                     # Skip this row if it became stale
#                     continue
#         else:
#             break

#         # Finding next page button
#         next_button = WebDriverWait(driver, 10).until(
#             EC.element_to_be_clickable((By.XPATH, "//a[@class='button' and @title='Successiva']"))
#         )

#         # Use JavaScript to click
#         driver.execute_script("arguments[0].click();", next_button)

#         # Waiting for the new content to load
#         time.sleep(2)

#     except Exception as e:
#         # print("No more pages or an error occurred:", e)
#         break

# %% [markdown]
# ## Getting pubblica number

# %%
body_e = driver.find_element(By.ID, 'tabella_albo')

rows_e = body_e.find_elements(By.CLASS_NAME, 'paginated_element')

# %%
for r_e in rows_e:
    # Find the div containing 'Numero progressivo:'
    pubblica_n = r_e.find_element(By.XPATH, ".//div[label/text()='Numero progressivo:']")

    print(pubblica_n.text)
# Out:
# 2024/0002737
# 2024/0002736
# 2024/0002735
# 2024/0002734
# 2024/0002733
# 2024/0002732
# 2024/0002731
# 2024/0002730
# 2024/0002729
# 2024/0002728
# 2024/0002727
# 2024/0002726
# 2024/0002725
# 2024/0002724
# 2024/0002723

# %%
def get_filename_from_cd(cd):
    if not cd:
        return None
    fname = None
    if 'filename=' in cd:
        fname = cd.split('filename=')[1]
        if '"' in fname:
            fname = fname.split('"')[1]
        else:
            fname = fname.split(';')[0].strip()
    return fname

# %%
def download_single_file_external_page(link_file_external: str) -> None:
    try:
        driver.get(link_file_external)
        scarica_button = driver.find_element(By.CLASS_NAME, 'btn.btn-primary')
        link_file = scarica_button.get_attribute('href')

        # Send a HEAD request to check the content type
        response = requests.head(link_file, allow_redirects=True)
        
        if 'Content-Type' in response.headers:
            content_type = response.headers['Content-Type']
            if 'application/pdf' in content_type:
                # This is a PDF file, download it
                response = requests.get(link_file)

                cd = response.headers.get('Content-Disposition')
                file_name = get_filename_from_cd(cd)

                # Construct the full path of the file
                file_path = Path(download_path, file_name)
                
                with open(file_path, 'wb') as file:
                    file.write(response.content)
    except Exception as e:
        logging.info(f'Could not get file from external link: {e}')

# %%
def download_single_file_atto_page(link: str):
    # Send a HEAD request to check the content type
    response = requests.head(link, allow_redirects=True)
    
    if 'Content-Type' in response.headers:
        content_type = response.headers['Content-Type']
        if 'application/pdf' in content_type:
            # This is a PDF file, download it
            response = requests.get(link)

            cd = response.headers.get('Content-Disposition')
            file_name = get_filename_from_cd(cd)

            # Construct the full path of the file
            file_path = Path(download_path, file_name)
            
            with open(file_path, 'wb') as file:
                file.write(response.content)
        else:
            download_single_file_external_page(link_file_external=link)
    else:
        print(f"No Content-Type header: {link}")

# %%
def get_dict_objects():
    try:
        body_e = driver.find_element(By.CLASS_NAME, 'card-body.pe-0.ps-4.ps-md-5')

        # Find the link element
        list_link_e = body_e.find_elements(By.TAG_NAME, 'a')
        list_link = [l_e.get_attribute('href') for l_e in list_link_e]

        print(f'Found {len(list_link_e)} elements')
        for l in list_link:
            file_path = download_single_file_atto_page(l)

        return file_path

    except Exception as e:
        logging.warning(f'Could not download files: {e}')

# %% [markdown]
# # Downloading files

# %%
# driver.get('https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=11479')
# get_dict_objects()

# %%
driver.get(url_comune)

body_e = driver.find_element(By.ID, 'tabella_albo')

rows_e = body_e.find_elements(By.CLASS_NAME, 'paginated_element')

# %%
links_atti = [r_e.find_element(By.TAG_NAME, 'a').get_attribute('href') for r_e in rows_e]

# %%
links_atti
# Out:
# ['https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13072&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13069&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13066&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13063&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13060&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13057&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12920&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13054&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13051&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13048&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13045&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13042&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13039&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13036&CSRF=1927596617c4488387ca3fcdde20d462',
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13033&CSRF=1927596617c4488387ca3fcdde20d462']

# %%
# for link in links_atti:
#     driver.get(link)
#     get_dict_objects()

# %% [markdown]
# # Class oggetti Ricerca

# %%
class SectionsAlbo:
    def __init__(self, url_comune: str, driver_manager: WebDriverManager, dir_download: str, last_date_update: datetime):
        self.url_comune = url_comune
        self.driver = driver_manager.get_driver(url_comune)
        self.dir_download = self.check_dir_download(dir_download)
        self.last_date_update = last_date_update
        self.dict_links_oggetti = self.loop_all_pages()


    @staticmethod
    def check_dir_download(dir_download):
        # Creating directory if does not exist:
        if not os.path.exists(dir_download):
            os.makedirs(dir_download)
        return dir_download
    

    @staticmethod
    def get_n_atto(ogg_e: WebElement)->str:
        try:
            pubblica_n = ogg_e.find_element(By.XPATH, ".//div[label/text()='Numero progressivo:']").text

            pubblica_pattern = r"2024/(\d+)"
            
            # Find matches in the string
            match = re.search(pubblica_pattern, pubblica_n)
            return match.group(1)
        except Exception as e:
            logging.warning(f'SectionsAlbo: Could not get n_atto: {e}')


    @staticmethod
    def get_start_date(ogg_e: WebElement) -> datetime:
        try:
            data_affissione = ogg_e.find_element(By.XPATH, ".//div[label/text()='Data affissione:']").text

            start_date = datetime.strptime(data_affissione, '%d/%m/%Y')

            return start_date
        except Exception as e:
            logging.warning(f'SectionsAlbo: Could not get start date: {e}')

    
    @staticmethod
    def get_end_date(ogg_e: WebElement) -> datetime:
        try:
            fine_pubblicazione = ogg_e.find_element(By.XPATH, ".//div[label/text()='Fine Pubblicazione:']").text
            
            end_date = datetime.strptime(fine_pubblicazione, '%d/%m/%Y')

            return end_date
        except Exception as e:
            logging.warning(f'SectionsAlbo: Could not get end date: {e}')

    
    @staticmethod
    def get_oggetto_link(ogg_e: WebElement)->str:
        try:
            a_element = ogg_e.find_element(By.TAG_NAME, 'a')
            return a_element.get_attribute('href')

        except Exception as e:
            logging.warning(f'SectionsAlbo: Could not get link from oggetto {e}')
        pass


    @staticmethod
    def rename_file(file_name:str, link_ogg: str)->str:
        # Generate a unique identifier for the file
        id = hashlib.sha256(link_ogg.encode()).hexdigest()[:8]

        return f'{id}_{file_name}'
    

    def get_main_info_oggetto(self, ogg_e: WebElement) -> dict:
        n_atto = self.get_n_atto(ogg_e=ogg_e)
        start_date = self.get_start_date(ogg_e=ogg_e)
        end_date = self.get_end_date(ogg_e=ogg_e)
        link = self.get_oggetto_link(ogg_e=ogg_e)
        
        return {link: dict(n_atto=n_atto,
                           start_date=start_date,
                           end_date=end_date)}


    def get_atti_from_page(self) -> dict:
        try:
            all_oggetti_page = {}
            # Waiting for the tabella element
            body_e = WebDriverWait(self.driver, 10).until(
                EC.presence_of_element_located((By.ID, 'tabella_albo'))
            )

            # Getting each row, one for each atto
            rows_e = body_e.find_elements(By.CLASS_NAME, 'paginated_element')

            # Process rows, one for atto
            if rows_e:
                for r_e in rows_e:
                    try:
                        start_date = self.get_start_date(r_e)
                        if (self.last_date_update == None) or (self.last_date_update < start_date.date()):
                            dict_ogg = self.get_main_info_oggetto(ogg_e=r_e)

                            all_oggetti_page.update(dict_ogg)
                        else:  # atto already in DB, skipping it
                            pass
                    except StaleElementReferenceException:  # Skip this row if it became stale
                        continue
            else:
                pass
        except:
            logging.warning(f'SectionsAlbo: Could not get the atti from this page: {e}')

        return all_oggetti_page


    def loop_all_pages(self) -> dict:
        all_oggetti_dict = {}
        self.driver.get(self.url_comune)

        page_number = 1
        while True:
            try:
                logging.info(f'Getting atti from page: {page_number}')
                dict_page = self.get_atti_from_page()
                all_oggetti_dict.update(dict_page)

                # Finding next page button
                next_button = WebDriverWait(self.driver, 10).until(
                    EC.element_to_be_clickable((By.XPATH, "//a[@class='button' and @title='Successiva']"))
                )

                # Use JavaScript to click
                self.driver.execute_script("arguments[0].click();", next_button)
                page_number += 1

                # Waiting for the new content to load
                time.sleep(2)

            except Exception as e:
                # print("No more pages or an error occurred:", e)
                break
        
        return all_oggetti_dict
    

    @staticmethod
    def get_filename_from_cd(cd):
        if not cd:
            return None
        fname = None
        if 'filename=' in cd:
            fname = cd.split('filename=')[1]
            if '"' in fname:
                fname = fname.split('"')[1]
            else:
                fname = fname.split(';')[0].strip()
        return fname
    

    def general_download(self, link_file:str)->Path:
        try: 
            response = requests.get(link_file)

            cd = response.headers.get('Content-Disposition')
            file_name = self.rename_file(self.get_filename_from_cd(cd))

            # Construct the full path of the file
            file_path = Path(download_path, file_name)
            
            with open(file_path, 'wb') as file:
                file.write(response.content)
            
            return file_name, link_file, file_path
        except Exception as e:
            logging.info(f'SectionsAlbo: Could not download file from {link_file}: {e}')
    

    def download_single_file_external_page(self, link_file_external: str) -> None:
        try:
            self.driver.get(link_file_external)
            scarica_button = self.driver.find_element(By.CLASS_NAME, 'btn.btn-primary')
            link_file = scarica_button.get_attribute('href')

            # Send a HEAD request to check the content type
            response = requests.head(link_file, allow_redirects=True)
            
            if 'Content-Type' in response.headers:
                content_type = response.headers['Content-Type']
                if 'application/pdf' in content_type:
                    # This is a PDF file, download it
                    f_name, f_link, f_path = self.general_download(link_file_external)
            return f_name, f_link, f_path
        except Exception as e:
            logging.info(f'SectionsAlbo: Could not get file from external link: {e}')


    def download_single_file_atto_page(self, link_ogg: str) -> Tuple[str, str, str]:
        """This method will get all the links available for a given atto, it will use the HEAD request 
        to check if it's possible to download a file from the given file, otherwise it probably it's an 
        external link, in this case it will open the external link and download the files from it.

        Args:
            link_ogg (str): Link of the atto.

        Returns:
            Tuple[str, str, str]: Name of the file, Link of the file, Path where it's been saved.
        """
        try:
            # Send a HEAD request to check the content type
            response = requests.head(link_ogg, allow_redirects=True)
            
            if 'Content-Type' in response.headers: 
                content_type = response.headers['Content-Type']
                # If the link has the file, download it
                if 'application/pdf' in content_type:
                    f_name, f_link, f_path = self.general_download(link_file=link_ogg)
                # Else maybe it's an external link, try to download it:
                else:
                    f_name, f_link, f_path = download_single_file_external_page(link_file_external=link)
                return f_name, f_link, f_path
            else:
                pass
        except Exception as e:
            logging.warning(f'SectionsAlbo: Could not download files from {link_ogg}')
    
    
    def get_dict_objects(self):
        dict_ogg = {}
        if self.dict_links_oggetti:
            logging.info(f'Found {len(self.dict_links_oggetti)} oggetti')
            for link, dict_info in self.dict_links_oggetti.items():
                self.driver.get(link)
                try:
                    body_e = driver.find_element(By.CLASS_NAME, 'card-body.pe-0.ps-4.ps-md-5')

                    # Find the link element
                    list_link_e = body_e.find_elements(By.TAG_NAME, 'a')
                    list_link = [l_e.get_attribute('href') for l_e in list_link_e]

                    for l in list_link:
                        try:
                            f_name, f_link, f_path = download_single_file_atto_page(l)

                            dict_ogg[f_name] = dict(**dict_info,
                                                    file_name= f_name,
                                                    link_file = f_link,
                                                    internal_path = f_path
                                                    )
                        except:
                            pass

                except Exception as e:
                    logging.warning(f'SectionsAlbo: Could not download files: {e}')
        else:
            logging.info(f'SectionsAlbo: All files up-to-date!')

# %%
sections_manager = SectionsAlbo(url_comune=url_comune,
                                driver_manager=driver_manager,
                                dir_download=download_path,
                                last_date_update=None)
# Out:
# INFO:root:Getting atti from page: 1
# INFO:root:Getting atti from page: 2
# INFO:root:Getting atti from page: 3
# INFO:root:Getting atti from page: 4
# INFO:root:Getting atti from page: 5
# INFO:root:Getting atti from page: 6
# INFO:root:Getting atti from page: 7
# INFO:root:Getting atti from page: 8
# INFO:root:Getting atti from page: 9
# INFO:root:Getting atti from page: 10
# INFO:root:Getting atti from page: 11
# INFO:root:Getting atti from page: 12
# INFO:root:Getting atti from page: 13
# INFO:root:Getting atti from page: 14
# INFO:root:Getting atti from page: 15
# INFO:root:Getting atti from page: 16
# INFO:root:Getting atti from page: 17
# INFO:root:Getting atti from page: 18
# INFO:root:Getting atti from page: 19
# INFO:root:Getting atti from page: 20
# INFO:root:Getting atti from page: 21
# INFO:root:Getting atti from page: 22
# INFO:root:Getting atti from page: 23
# INFO:root:Getting atti from page: 24
# INFO:root:Getting atti from page: 25
# INFO:root:Getting atti from page: 26

# %%
sections_manager.dict_links_oggetti
# Out:
# {'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13072&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002737',
#   'start_date': datetime.datetime(2024, 6, 6, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13069&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002736',
#   'start_date': datetime.datetime(2024, 6, 6, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 21, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13066&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002735',
#   'start_date': datetime.datetime(2024, 6, 6, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 21, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13063&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002734',
#   'start_date': datetime.datetime(2024, 6, 6, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 21, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13060&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002733',
#   'start_date': datetime.datetime(2024, 6, 6, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 21, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13057&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002732',
#   'start_date': datetime.datetime(2024, 6, 6, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 21, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12920&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002731',
#   'start_date': datetime.datetime(2024, 6, 6, 0, 0),
#   'end_date': datetime.datetime(2024, 7, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13054&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002730',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13051&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002729',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13048&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002728',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13045&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002727',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13042&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002726',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13039&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002725',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13036&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002724',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13033&CSRF=1927596617c4488387ca3fcdde20d462': {'n_atto': '0002723',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13030': {'n_atto': '0002722',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13027': {'n_atto': '0002721',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13024': {'n_atto': '0002720',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13021': {'n_atto': '0002719',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 7, 5, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13018': {'n_atto': '0002718',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13015': {'n_atto': '0002717',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13012': {'n_atto': '0002716',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13009': {'n_atto': '0002715',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13006': {'n_atto': '0002714',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13003': {'n_atto': '0002713',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=13000': {'n_atto': '0002712',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12997': {'n_atto': '0002711',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12994': {'n_atto': '0002710',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12991': {'n_atto': '0002709',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12988': {'n_atto': '0002708',
#   'start_date': datetime.datetime(2024, 6, 5, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 20, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=
 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12724': {'n_atto': '0002613',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12721': {'n_atto': '0002612',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12718': {'n_atto': '0002611',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12715': {'n_atto': '0002610',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12712': {'n_atto': '0002609',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12709': {'n_atto': '0002608',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 30, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12706': {'n_atto': '0002607',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12703': {'n_atto': '0002606',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12700': {'n_atto': '0002605',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12697': {'n_atto': '0002604',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12694': {'n_atto': '0002603',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12693': {'n_atto': '0002602',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12692': {'n_atto': '0002601',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 7, 9, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12691': {'n_atto': '0002600',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12688': {'n_atto': '0002599',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12687': {'n_atto': '0002598',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12686': {'n_atto': '0002597',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12685': {'n_atto': '0002596',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12682': {'n_atto': '0002595',
#   'start_date': datetime.datetime(2024, 5, 31, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 15, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12679': {'n_atto': '0002594',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12676': {'n_atto': '0002593',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12673': {'n_atto': '0002592',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12670': {'n_atto': '0002591',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12667': {'n_atto': '0002590',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12664': {'n_atto': '0002589',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12661': {'n_atto': '0002588',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12658': {'n_atto': '0002587',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12655': {'n_atto': '0002586',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12652': {'n_atto': '0002585',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12649': {'n_atto': '0002584',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12646': {'n_atto': '0002583',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12643': {'n_atto': '0002582',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12640': {'n_atto': '0002581',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12637': {'n_atto': '0002580',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12634': {'n_atto': '0002579',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12631': {'n_atto': '0002578',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12628': {'n_atto': '0002577',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12625': {'n_atto': '0002576',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12622': {'n_atto': '0002575',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12619': {'n_atto': '0002574',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12616': {'n_atto': '0002573',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12613': {'n_atto': '0002572',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12610': {'n_atto': '0002571',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12607': {'n_atto': '0002570',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12604': {'n_atto': '0002569',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12601': {'n_atto': '0002568',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12598': {'n_atto': '0002567',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12595': {'n_atto': '0002566',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12592': {'n_atto': '0002565',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12589': {'n_atto': '0002564',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12586': {'n_atto': '0002563',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12583': {'n_atto': '0002562',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12580': {'n_atto': '0002561',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12577': {'n_atto': '0002560',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12574': {'n_atto': '0002559',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12571': {'n_atto': '0002558',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12568': {'n_atto': '0002557',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12565': {'n_atto': '0002556',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12563': {'n_atto': '0002555',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 29, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12562': {'n_atto': '0002554',
#   'start_date': datetime.datetime(2024, 5, 30, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12560': {'n_atto': '0002553',
#   'start_date': datetime.datetime(2024, 5, 29, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=

#   'start_date': datetime.datetime(2024, 5, 24, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12136': {'n_atto': '0002395',
#   'start_date': datetime.datetime(2024, 5, 24, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12133': {'n_atto': '0002394',
#   'start_date': datetime.datetime(2024, 5, 24, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12130': {'n_atto': '0002393',
#   'start_date': datetime.datetime(2024, 5, 24, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12127': {'n_atto': '0002392',
#   'start_date': datetime.datetime(2024, 5, 24, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12124': {'n_atto': '0002391',
#   'start_date': datetime.datetime(2024, 5, 24, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12121': {'n_atto': '0002389',
#   'start_date': datetime.datetime(2024, 5, 23, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 7, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12118': {'n_atto': '0002388',
#   'start_date': datetime.datetime(2024, 5, 23, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 7, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12115': {'n_atto': '0002387',
#   'start_date': datetime.datetime(2024, 5, 23, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 7, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12112': {'n_atto': '0002386',
#   'start_date': datetime.datetime(2024, 5, 23, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 7, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12109': {'n_atto': '0002385',
#   'start_date': datetime.datetime(2024, 5, 23, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 7, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12106': {'n_atto': '0002384',
#   'start_date': datetime.datetime(2024, 5, 23, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 7, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12100': {'n_atto': '0002382',
#   'start_date': datetime.datetime(2024, 5, 23, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 7, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12097': {'n_atto': '0002381',
#   'start_date': datetime.datetime(2024, 5, 23, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 7, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12094': {'n_atto': '0002380',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12091': {'n_atto': '0002379',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12088': {'n_atto': '0002378',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12085': {'n_atto': '0002377',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12082': {'n_atto': '0002376',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12079': {'n_atto': '0002375',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12076': {'n_atto': '0002374',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12073': {'n_atto': '0002372',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12070': {'n_atto': '0002371',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12067': {'n_atto': '0002370',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12064': {'n_atto': '0002369',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12061': {'n_atto': '0002368',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12058': {'n_atto': '0002367',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12055': {'n_atto': '0002366',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12052': {'n_atto': '0002365',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12049': {'n_atto': '0002364',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12046': {'n_atto': '0002363',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12043': {'n_atto': '0002362',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12040': {'n_atto': '0002361',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12037': {'n_atto': '0002360',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12031': {'n_atto': '0002358',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12028': {'n_atto': '0002357',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 7, 21, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12025': {'n_atto': '0002355',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12022': {'n_atto': '0002354',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12019': {'n_atto': '0002353',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12016': {'n_atto': '0002352',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=12013': {'n_atto': '0002351',
#   'start_date': datetime.datetime(2024, 5, 22, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=11959': {'n_atto': '0002331',
#   'start_date': datetime.datetime(2024, 5, 20, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=11956': {'n_atto': '0002330',
#   'start_date': datetime.datetime(2024, 5, 20, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 6, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=11738': {'n_atto': '0002249',
#   'start_date': datetime.datetime(2024, 5, 15, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 8, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=11479': {'n_atto': '0002159',
#   'start_date': datetime.datetime(2024, 5, 13, 0, 0),
#   'end_date': datetime.datetime(2024, 7, 12, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=10695': {'n_atto': '0001879',
#   'start_date': datetime.datetime(2024, 4, 29, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 9, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=10610': {'n_atto': '0001845',
#   'start_date': datetime.datetime(2024, 4, 25, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 9, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=9129': {'n_atto': '0001316',
#   'start_date': datetime.datetime(2024, 3, 27, 0, 0),
#   'end_date': datetime.datetime(2024, 6, 21, 0, 0)},
#  'https://servizi.comune.brindisi.it/openweb/albo/albo_dettagli.php?id=7403': {'n_atto': '0000709',
#   'start_date': datetime.datetime(2024, 2, 29, 0, 0),
#   'end_date': datetime.datetime(2024, 7, 31, 0, 0)}}

# %%
link_test = 'https://servizi.comune.brindisi.it/openweb/portal/getDoc.php?f=documenti/12046_OrdinanzaDirigenziale_Copia_234_2024.pdf&CSRF=15cc9dc472f067906deda9617571a671'

# %%
link_test.split('&')[0].split('/')[-1]
# Out:
# '12046_OrdinanzaDirigenziale_Copia_234_2024.pdf'
